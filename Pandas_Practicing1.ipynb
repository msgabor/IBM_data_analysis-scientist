# %%
# !pip install xlrd

# %%
import pandas as pd

# %%
pd.read_table('http://bit.ly/chiporders')
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
pd.read_table('http://bit.ly/movieusers')
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
pd.read_table('http://bit.ly/movieusers', sep='|', header=None)
# Out:
#        0   1  2              3      4
# 0      1  24  M     technician  85711
# 1      2  53  F          other  94043
# 2      3  23  M         writer  32067
# 3      4  24  M     technician  43537
# 4      5  33  F          other  15213
# ..   ...  .. ..            ...    ...
# 938  939  26  F        student  33319
# 939  940  32  M  administrator  02215
# 940  941  20  M        student  97229
# 941  942  48  F      librarian  78209
# 942  943  22  M        student  77841
#
# [943 rows x 5 columns]

# %%
user_columns = ['user_id','age','gender', 'job_title', 'zip_code']
final_list = pd.read_table('http://bit.ly/movieusers', sep='|', header=None, names=user_columns)

# %%
final_list.head(1000)
# Out:
#      user_id  age gender      job_title zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
import pandas as pd

# %%
ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo.head(10000)
# Out:
#                       City Colors Reported Shape Reported State  \
# 0                   Ithaca             NaN       TRIANGLE    NY
# 1              Willingboro             NaN          OTHER    NJ
# 2                  Holyoke             NaN           OVAL    CO
# 3                  Abilene             NaN           DISK    KS
# 4     New York Worlds Fair             NaN          LIGHT    NY
# ...                    ...             ...            ...   ...
# 9995               Phoenix             NaN       TRIANGLE    AZ
# 9996               Phoenix             NaN       TRIANGLE    AZ
# 9997               Phoenix             NaN       TRIANGLE    AZ
# 9998               Phoenix             NaN            NaN    AZ
# 9999                 Tempe             NaN          OTHER    AZ
#
#                  Time
# 0      6/1/1930 22:00
# 1     6/30/1930 20:00
# 2     2/15/1931 14:00
# 3      6/1/1931 13:00
# 4     4/18/1933 19:00
# ...               ...
# 9995  3/13/1997 20:00
# ...

# %%
ufo["City"]
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
ufo.City
# Out:
# 0                      Ithaca
# 1                 Willingboro
# 2                     Holyoke
# 3                     Abilene
# 4        New York Worlds Fair
#                  ...
# 18236              Grant Park
# 18237             Spirit Lake
# 18238             Eagle River
# 18239             Eagle River
# 18240                    Ybor
# Name: City, Length: 18241, dtype: object

# %%
ufo["Colors Reported"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18236    NaN
# 18237    NaN
# 18238    NaN
# 18239    RED
# 18240    NaN
# Name: Colors Reported, Length: 18241, dtype: object

# %%
ufo["Location"] = ufo.City + " - " +ufo.State

# %%
ufo.head(10000)
# Out:
#                       City Colors Reported Shape Reported State  \
# 0                   Ithaca             NaN       TRIANGLE    NY
# 1              Willingboro             NaN          OTHER    NJ
# 2                  Holyoke             NaN           OVAL    CO
# 3                  Abilene             NaN           DISK    KS
# 4     New York Worlds Fair             NaN          LIGHT    NY
# ...                    ...             ...            ...   ...
# 9995               Phoenix             NaN       TRIANGLE    AZ
# 9996               Phoenix             NaN       TRIANGLE    AZ
# 9997               Phoenix             NaN       TRIANGLE    AZ
# 9998               Phoenix             NaN            NaN    AZ
# 9999                 Tempe             NaN          OTHER    AZ
#
#                  Time                   Location
# 0      6/1/1930 22:00                Ithaca - NY
# 1     6/30/1930 20:00           Willingboro - NJ
# ...
