# %%
import pandas as pd
movies = pd.read_csv("http://bit.ly/imdbratings")
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe()
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.describe(include = ["object"])
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
movies.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
movies.rename(columns = {"star_rating" : "Star Rating", "title" : "Title", "content_rating" : "Content Rating", "genre" : "Genre", "duration" : "Duration", "actors_list":"Actors List"})
# Out:
#      Star Rating                                            Title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     Content Rating      Genre  Duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.columns = movies.columns.str.replace(" ", "_")

# %%
movies.head(1000)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
movies.drop("genre", axis = 1, inplace=True)

# %%
movies.head(1000)
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating  duration  \
# 0                R       142
# 1                R       175
# 2                R       200
# 3            PG-13       152
# ...

# %%
movies.drop([0,1], axis=0, inplace=True)

# %%
movies.head()
# Out:
#    star_rating                           title content_rating  duration  \
# 2          9.1          The Godfather: Part II              R       200
# 3          9.0                 The Dark Knight          PG-13       152
# 4          8.9                    Pulp Fiction              R       154
# 5          8.9                    12 Angry Men      NOT RATED        96
# 6          8.9  The Good, the Bad and the Ugly      NOT RATED       161
#
#                                          actors_list
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....
# 5  [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 6  [u'Clint Eastwood', u'Eli Wallach', u'Lee Van ...

# %% [markdown]
# #### Axes 0 is the column axis, axes 1 is the row axis

# %%
movies["title"].sort_values(ascending=True)
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 977, dtype: object

# %%
movies["title"]
# Out:
# 2                               The Godfather: Part II
# 3                                      The Dark Knight
# 4                                         Pulp Fiction
# 5                                         12 Angry Men
# 6                       The Good, the Bad and the Ugly
#                             ...
# 974                                            Tootsie
# 975                        Back to the Future Part III
# 976    Master and Commander: The Far Side of the World
# 977                                        Poltergeist
# 978                                        Wall Street
# Name: title, Length: 977, dtype: object

# %%
movies.sort_values("title")
# Out:
#      star_rating                  title content_rating  duration  \
# 542          7.8   (500) Days of Summer          PG-13        95
# 5            8.9           12 Angry Men      NOT RATED        96
# 201          8.1       12 Years a Slave              R       134
# 698          7.6              127 Hours              R        94
# 110          8.3  2001: A Space Odyssey              G       160
# ..           ...                    ...            ...       ...
# 955          7.4       Zero Dark Thirty              R       157
# 677          7.7                 Zodiac              R       157
# 615          7.7             Zombieland              R        88
# 526          7.8                   Zulu        UNRATED       138
# 864          7.5                  [Rec]              R        78
#
#                                            actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# ...

# %%
movies.sort_values("duration")
# Out:
#      star_rating                              title content_rating  duration  \
# 389          8.0                             Freaks        UNRATED        64
# 338          8.0                Battleship Potemkin        UNRATED        66
# 258          8.1        The Cabinet of Dr. Caligari        UNRATED        67
# 88           8.4                            The Kid      NOT RATED        68
# 293          8.1                          Duck Soup         PASSED        68
# ..           ...                                ...            ...       ...
# 445          7.9               The Ten Commandments       APPROVED       220
# 142          8.3  Lagaan: Once Upon a Time in India             PG       224
# 78           8.4        Once Upon a Time in America              R       229
# 157          8.2                 Gone with the Wind              G       238
# 476          7.8                             Hamlet          PG-13       242
#
# ...

# %%
movies.sort_values(["content_rating", "duration"])
# Out:
#      star_rating                               title content_rating  duration  \
# 713          7.6                     The Jungle Book       APPROVED        78
# 513          7.8      Invasion of the Body Snatchers       APPROVED        80
# 272          8.1                         The Killing       APPROVED        85
# 703          7.6                             Dracula       APPROVED        85
# 612          7.7                  A Hard Day's Night       APPROVED        87
# ..           ...                                 ...            ...       ...
# 387          8.0                     Midnight Cowboy              X       113
# 86           8.4                  A Clockwork Orange              X       136
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN       110
# 936          7.4                           True Grit            NaN       128
# 649          7.7                   Where Eagles Dare            NaN       158
#
# ...

# %%
import pandas as pd
movies = pd.read_csv("http://bit.ly/imdbratings", usecols = ["title", "duration"])
movies.head(1000)
# Out:
#                                                title  duration
# 0                           The Shawshank Redemption       142
# 1                                      The Godfather       175
# 2                             The Godfather: Part II       200
# 3                                    The Dark Knight       152
# 4                                       Pulp Fiction       154
# ..                                               ...       ...
# 974                                          Tootsie       116
# 975                      Back to the Future Part III       118
# 976  Master and Commander: The Far Side of the World       138
# 977                                      Poltergeist       114
# 978                                      Wall Street       126
#
# [979 rows x 2 columns]

# %%
movies = pd.read_csv("http://bit.ly/imdbratings", usecols = ["title", "duration"], nrows = 25)
movies.head(25)
# Out:
#                                                 title  duration
# 0                            The Shawshank Redemption       142
# 1                                       The Godfather       175
# 2                              The Godfather: Part II       200
# 3                                     The Dark Knight       152
# 4                                        Pulp Fiction       154
# 5                                        12 Angry Men        96
# 6                      The Good, the Bad and the Ugly       161
# 7       The Lord of the Rings: The Return of the King       201
# 8                                    Schindler's List       195
# 9                                          Fight Club       139
# 10  The Lord of the Rings: The Fellowship of the Ring       178
# 11                                          Inception       148
# 12     Star Wars: Episode V - The Empire Strikes Back       124
# 13                                       Forrest Gump       142
# ...
